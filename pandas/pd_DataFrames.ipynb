# %% [markdown]
# ## DataFrames
#
# Throughout the course, most of our data exploration will be done with DataFrames. DataFrames are an extremely powerful tool and a natural extension of the Pandas Series. By definition all a DataFrame is:
#
# **A Pandas DataFrame consists of multiple Pandas Series that share index values.**

# %% [markdown]
# ## imports

# %%
import numpy as np
import pandas as pd

# %%
# Make sure the seed is in the same cell as the random call
# https://stackoverflow.com/questions/21494489/what-does-numpy-random-seed0-do
np.random.seed(101)
mydata = np.random.randint(0,101,(4,3))
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myindex = ['CA','NY','AZ','TX']
mycolumns = ['Jan','Feb','Mar']
df = pd.DataFrame(data=mydata)
df
# Out:
#     0   1   2
# 0  95  11  81
# 1  70  63  87
# 2  75   9  77
# 3  40   4  63

# %%
df = pd.DataFrame(data=mydata,index=myindex)
df
# Out:
#      0   1   2
# CA  95  11  81
# NY  70  63  87
# AZ  75   9  77
# TX  40   4  63

# %%
df = pd.DataFrame(data=mydata,index=myindex,columns=mycolumns)
df
# Out:
#     Jan  Feb  Mar
# CA   95   11   81
# NY   70   63   87
# AZ   75    9   77
# TX   40    4   63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to TX
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int64
#  1   Feb     4 non-null      int64
#  2   Mar     4 non-null      int64
# dtypes: int64(3)
# memory usage: 128.0+ bytes

# %% [markdown]
# ## load csv

# %%
df = pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().T
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %% [markdown]
# ## column/columns filtering

# %%
selected_columns = ['total_bill', 'tip']
df[selected_columns]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df[['total_bill', 'tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %% [markdown]
# ## columns conditional filtering based other column condition

# %%
import pandas as pd

data = {
    'A': [10, 20, 30, 40, 50],
    'B': [5, 15, 25, 35, 45],
    'C': [100, 200, 300, 400, 500]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     A   B    C
# 0  10   5  100
# 1  20  15  200
# 2  30  25  300
# 3  40  35  400
# 4  50  45  500

# %%
filtered_A = df['A'][df['B'] > 20]
print(filtered_A)
# Out:
# 2    30
# 3    40
# 4    50
# Name: A, dtype: int64

# %% [markdown]
# Multiple Conditions <br>
# bitwise operators `(& for "and", | for "or")`:

# %%
filtered_A = df['A'][(df['B'] > 20) & (df['C'] < 450)]
filtered_A
# Out:
# 2    30
# 3    40
# Name: A, dtype: int64

# %% [markdown]
# ## `filter` a Pandas dataframe where a specific column contains the substring

# %%
import pandas as pd

# Sample DataFrame
data = {'ID': [1, 2, 3, 4],
        'Name': ['N7X Model', 'X9 Model', 'N7S Model', 'Z4 Model']}
df = pd.DataFrame(data)

# Filter rows where 'Name' column contains 'N7'
filtered_df = df[df['Name'].str.contains('N7')]

filtered_df
# Out:
#    ID       Name
# 0   1  N7X Model
# 2   3  N7S Model

# %% [markdown]
# ## `filter` a Pandas dataframe where a specific column **does not** contains the substring

# %%
import pandas as pd

# Sample DataFrame
data = {'ID': [1, 2, 3, 4],
        'Name': ['N7X Model', 'X9 Model', 'N7S Model', 'Z4 Model']}
df = pd.DataFrame(data)

# Filter rows where 'Name' column does NOT contain the string 'N7'
filtered_df = df[~df['Name'].str.contains('N7')]

print(filtered_df)
# Out:
#    ID      Name
# 1   2  X9 Model
# 3   4  Z4 Model

# %% [markdown]
# ## `Convert` 'numbers' column to integer using `pd.to_numeric()`

# %%
import pandas as pd

# Sample DataFrame with 'numbers' as strings
data = {'ID': [1, 2, 3, 4],
        'numbers': ['100', '200', '300', '400']}
df = pd.DataFrame(data)

# Convert 'numbers' column to integer using pd.to_numeric()
df['numbers'] = pd.to_numeric(df['numbers'])

print(df)
print(df.dtypes)  # To check the data types
# Out:
#    ID  numbers
# 0   1      100
# 1   2      200
# 2   3      300
# 3   4      400
# ID         int64
# numbers    int64
# dtype: object

# %% [markdown]
# `Convert` with `astype()`

# %%
# Convert 'numbers' column to integer using astype()
df['numbers'] = df['numbers'].astype(int)

print(df)
print(df.dtypes)  # To check the data types
# Out:
#    ID  numbers
# 0   1      100
# 1   2      200
# 2   3      300
# 3   4      400
# ID         int64
# numbers    int64
# dtype: object

# %% [markdown]
# ## `filter` column with conditional with `or` ith (`|`) keyword

# %%
import pandas as pd

# Sample DataFrame
data = {'ID': [1, 2, 3, 4, 5],
        'numbers': [650, 710, 680, 760, 720]}
df = pd.DataFrame(data)

# Filter rows where 'numbers' column is less than 700 or greater than 749
filtered_df = df[(df['numbers'] < 700) | (df['numbers'] > 749)]

filtered_df
# Out:
#    ID  numbers
# 0   1      650
# 2   3      680
# 3   4      760

# %% [markdown]
# ## manipulations on columns

# %%
df['tip'] + df['total_bill']
# Out:
# 0      18.00
# 1      12.00
# 2      24.51
# 3      26.99
# 4      28.20
#        ...
# 239    34.95
# 240    29.18
# 241    24.67
# 242    19.57
# 243    21.78
# Length: 244, dtype: float64

# %%
100*df['tip'] / df['total_bill']
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
#          ...
# 239    20.392697
# 240     7.358352
# 241     8.822232
# 242     9.820426
# 243    15.974441
# Length: 244, dtype: float64

# %% [markdown]
# ## Insert column into DataFrame at specified location.

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.insert(1, "newcol", None)
df
# Out:
#      total_bill newcol   tip     sex smoker   day    time  size  \
# 0         16.99   None  1.01  Female     No   Sun  Dinner     2
# 1         10.34   None  1.66    Male     No   Sun  Dinner     3
# 2         21.01   None  3.50    Male     No   Sun  Dinner     3
# 3         23.68   None  3.31    Male     No   Sun  Dinner     2
# 4         24.59   None  3.61  Female     No   Sun  Dinner     4
# ..          ...    ...   ...     ...    ...   ...     ...   ...
# 239       29.03   None  5.92    Male     No   Sat  Dinner     3
# 240       27.18   None  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67   None  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82   None  1.75    Male     No   Sat  Dinner     2
# 243       18.78   None  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number Payment ID
# 0                8.49  Christy Cunningham  3560325168603410    Sun2959
# 1                3.45      Douglas Tucker  4478071379779230    Sun4608
# 2                7.00      Travis Walters  6011812112971322    Sun4458
# 3               11.84    Nathaniel Harris  4676137647685994    Sun5260
# 4                6.15        Tonya Carter  4832732618637221    Sun2251
# ..                ...                 ...               ...        ...
# 239              9.68       Michael Avila  5296068606052842    Sat2657
# 240             13.59      Monica Sanders  3506806155565404    Sat1766
# 241             11.34          Keith Wong  6011891618747196    Sat3880
# 242              8.91        Dennis Dixon     4375220550950      Sat17
# 243              9.39     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 12 columns]

# %%
#  insert multiple columns, at same time ,

# %%
# remove columns with index
# remove columns with colName

# %%
df = pd.read_csv('tips.csv')
# df.head()
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
print(df.shape)
df.head()
# Out:
# (244, 11)
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# ## set index column values as index

# %%
df.set_index('Payment ID')   # does not change dataframe itself
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
# ...                      ...                 ...               ...
# Sat2657                 9.68       Michael Avila  5296068606052842
# Sat1766                13.59      Monica Sanders  3506806155565404
# Sat3880                11.34          Keith Wong  6011891618747196
# Sat17                   8.91        Dennis Dixon     4375220550950
# Thur672                 9.39     Michelle Hardin  3511451626698139
#
# [244 rows x 10 columns]

# %%
df = df.set_index('Payment ID') 
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %% [markdown]
# ## reset index

# %%
df = df.reset_index()
df.head()
# Out:
#    index Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0      0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1      1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2      2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3      3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4      4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number
# 0              8.49  Christy Cunningham  3560325168603410
# 1              3.45      Douglas Tucker  4478071379779230
# 2              7.00      Travis Walters  6011812112971322
# 3             11.84    Nathaniel Harris  4676137647685994
# 4              6.15        Tonya Carter  4832732618637221

# %% [markdown]
# ## index location and label location  (iloc, loc)

# %%
df = df.set_index('Payment ID') 
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
# ...                      ...                 ...               ...
# Sat2657                 9.68       Michael Avila  5296068606052842
# Sat1766                13.59      Monica Sanders  3506806155565404
# Sat3880                11.34          Keith Wong  6011891618747196
# Sat17                   8.91        Dennis Dixon     4375220550950
# Thur672                 9.39     Michelle Hardin  3511451626698139
#
# [244 rows x 10 columns]

# %%
# accesing with integer location index,location
df.iloc[0]
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
# label location, 
df.loc['Sun4458']
# Out:
# total_bill                     21.01
# tip                              3.5
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               3
# price_per_person                 7.0
# Payer Name            Travis Walters
# CC Number           6011812112971322
# Name: Sun4458, dtype: object

# %% [markdown]
# ## slicing with iloc and loc

# %%
df.iloc[2: 10]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
# Sun5985           8.77  2.00    Male     No  Sun  Dinner     2
# Sun8157          26.88  3.12    Male     No  Sun  Dinner     4
# Sun6820          15.04  1.96    Male     No  Sun  Dinner     2
# Sun3775          14.78  3.23    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
# Sun9679                 6.32          Erik Smith   213140353657882
# Sun5985                 4.38  Kristopher Johnson  2223727524230344
# Sun8157                 6.72         Robert Buck  3514785077705092
# Sun6820                 7.52     Joseph Mcdonald  3522866365840377
# Sun3775                 7.39       Jerome Abbott  3532124519049786

# %%
df.loc[['Sun5260', 'Sun6820', 'Sun6820']]
# Out:
#             total_bill   tip   sex smoker  day    time  size  \
# Payment ID
# Sun5260          23.68  3.31  Male     No  Sun  Dinner     2
# Sun6820          15.04  1.96  Male     No  Sun  Dinner     2
# Sun6820          15.04  1.96  Male     No  Sun  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun5260                11.84  Nathaniel Harris  4676137647685994
# Sun6820                 7.52   Joseph Mcdonald  3522866365840377
# Sun6820                 7.52   Joseph Mcdonald  3522866365840377

# %% [markdown]
# ## append/concat one row horizontal

# %%
df = pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %%
one_row = pd.DataFrame(df.iloc[0]).T
one_row
# Out:
#   total_bill   tip     sex smoker  day    time size price_per_person  \
# 0      16.99  1.01  Female     No  Sun  Dinner    2             8.49
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959

# %%
pd.concat([df, one_row], ignore_index=True)
# Out:
#     total_bill   tip     sex smoker   day    time size price_per_person  \
# 0        16.99  1.01  Female     No   Sun  Dinner    2             8.49
# 1        10.34  1.66    Male     No   Sun  Dinner    3             3.45
# 2        21.01   3.5    Male     No   Sun  Dinner    3              7.0
# 3        23.68  3.31    Male     No   Sun  Dinner    2            11.84
# 4        24.59  3.61  Female     No   Sun  Dinner    4             6.15
# ..         ...   ...     ...    ...   ...     ...  ...              ...
# 240      27.18   2.0  Female    Yes   Sat  Dinner    2            13.59
# 241      22.67   2.0    Male    Yes   Sat  Dinner    2            11.34
# 242      17.82  1.75    Male     No   Sat  Dinner    2             8.91
# 243      18.78   3.0  Female     No  Thur  Dinner    2             9.39
# 244      16.99  1.01  Female     No   Sun  Dinner    2             8.49
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
# 244  Christy Cunningham  3560325168603410    Sun2959
#
# [245 rows x 11 columns]

# %% [markdown]
# ## drop rows

# %%
df = pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %%
# not in place operation
df.drop(243)
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 238      Kimberly Crane      676184013727    Sat9777
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
#
# [243 rows x 11 columns]

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %% [markdown]
# ## drop column

# %%
df.drop('total_bill', axis=1)   # Dropping a column in-place  inplace=True
# Out:
#       tip     sex smoker   day    time  size  price_per_person  \
# 0    1.01  Female     No   Sun  Dinner     2              8.49
# 1    1.66    Male     No   Sun  Dinner     3              3.45
# 2    3.50    Male     No   Sun  Dinner     3              7.00
# 3    3.31    Male     No   Sun  Dinner     2             11.84
# 4    3.61  Female     No   Sun  Dinner     4              6.15
# ..    ...     ...    ...   ...     ...   ...               ...
# 239  5.92    Male     No   Sat  Dinner     3              9.68
# 240  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242  1.75    Male     No   Sat  Dinner     2              8.91
# 243  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 10 columns]

# %% [markdown]
# ## `Filter` by single condition

# %% [markdown]
# ![image.png](attachment:image.png)
# - returns boolean series

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
bool_series = df['total_bill'] > 40
bool_series
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: total_bill, Length: 244, dtype: bool

# %%
df[bool_series]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 142       41.19   5.00    Male     No  Thur   Lunch     5              8.24
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2             20.27
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4             10.78
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID
# 59       Brian Ortiz  6596453823950595    Sat8139
# 95     Aaron Bentley   180026611638690    Fri9628
# 102    Heather Cohen   379771118886604    Sat6240
# 142     Eric Andrews  4356531761046453   Thur3621
# 156    Ryan Gonzales  3523151482063321    Sun7518
# 170    Gregory Clark  5473850968388236    Sat1954
# 182     Jose Parsons  4112207559459910    Sun2337
# 184      Stephen Cox  3547798222044029    Sun5140
# 197      Brooke Soto  5544902205760175   Thur9313
# 212  Alex Williamson      676218815212    Sat4590

# %%
df[df['total_bill'] > 40]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 142       41.19   5.00    Male     No  Thur   Lunch     5              8.24
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2             20.27
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4             10.78
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID
# 59       Brian Ortiz  6596453823950595    Sat8139
# 95     Aaron Bentley   180026611638690    Fri9628
# 102    Heather Cohen   379771118886604    Sat6240
# 142     Eric Andrews  4356531761046453   Thur3621
# 156    Ryan Gonzales  3523151482063321    Sun7518
# 170    Gregory Clark  5473850968388236    Sat1954
# 182     Jose Parsons  4112207559459910    Sun2337
# 184      Stephen Cox  3547798222044029    Sun5140
# 197      Brooke Soto  5544902205760175   Thur9313
# 212  Alex Williamson      676218815212    Sat4590

# %%
df[df['sex'] == 'Male']
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 1         10.34  1.66  Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50  Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31  Male     No  Sun  Dinner     2             11.84
# 5         25.29  4.71  Male     No  Sun  Dinner     4              6.32
# 6          8.77  2.00  Male     No  Sun  Dinner     2              4.38
# ..          ...   ...   ...    ...  ...     ...   ...               ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2              6.30
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2             16.42
# 239       29.03  5.92  Male     No  Sat  Dinner     3              9.68
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75  Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 5            Erik Smith   213140353657882    Sun9679
# 6    Kristopher Johnson  2223727524230344    Sun5985
# ..                  ...               ...        ...
# 236       Matthew Myers  3543676378973965    Sat5032
# 237        Thomas Brown  4284722681265508    Sat2929
# 239       Michael Avila  5296068606052842    Sat2657
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
#
# [157 rows x 11 columns]

# %% [markdown]
# `Filter` by multiple condition

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df[(df['sex'] == 'Male') & (df['total_bill'] > 40)]
# Out:
#      total_bill    tip   sex smoker   day    time  size  price_per_person  \
# 59        48.27   6.73  Male     No   Sat  Dinner     4             12.07
# 95        40.17   4.73  Male    Yes   Fri  Dinner     4             10.04
# 142       41.19   5.00  Male     No  Thur   Lunch     5              8.24
# 156       48.17   5.00  Male     No   Sun  Dinner     6              8.03
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3             16.94
# 182       45.35   3.50  Male    Yes   Sun  Dinner     3             15.12
# 184       40.55   3.00  Male    Yes   Sun  Dinner     2             20.27
# 212       48.33   9.00  Male     No   Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID
# 59       Brian Ortiz  6596453823950595    Sat8139
# 95     Aaron Bentley   180026611638690    Fri9628
# 142     Eric Andrews  4356531761046453   Thur3621
# 156    Ryan Gonzales  3523151482063321    Sun7518
# 170    Gregory Clark  5473850968388236    Sat1954
# 182     Jose Parsons  4112207559459910    Sun2337
# 184      Stephen Cox  3547798222044029    Sun5140
# 212  Alex Williamson      676218815212    Sat4590

# %%
df[(df['sex'] == 'Male') | (df['tip'] > 10)]
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 1         10.34  1.66  Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50  Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31  Male     No  Sun  Dinner     2             11.84
# 5         25.29  4.71  Male     No  Sun  Dinner     4              6.32
# 6          8.77  2.00  Male     No  Sun  Dinner     2              4.38
# ..          ...   ...   ...    ...  ...     ...   ...               ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2              6.30
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2             16.42
# 239       29.03  5.92  Male     No  Sat  Dinner     3              9.68
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75  Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 5            Erik Smith   213140353657882    Sun9679
# 6    Kristopher Johnson  2223727524230344    Sun5985
# ..                  ...               ...        ...
# 236       Matthew Myers  3543676378973965    Sat5032
# 237        Thomas Brown  4284722681265508    Sat2929
# 239       Michael Avila  5296068606052842    Sat2657
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
#
# [157 rows x 11 columns]

# %%
option = ['Sun', 'Sat']
df['day'].isin(option)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 239     True
# 240     True
# 241     True
# 242     True
# 243    False
# Name: day, Length: 244, dtype: bool

# %%
df[df['day'].isin(option)]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 238      Kimberly Crane      676184013727    Sat9777
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
#
# [163 rows x 11 columns]

# %% [markdown]
# ## `Filter` substring Using `str.contains(substring)`

# %%
# Checking for substring 'an' in the 'Name' column
substring = 'Christy'
df[df['Payer Name'].str.contains(substring)]
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959

# %% [markdown]
# ## `apply()` ***single*** column

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
# define dummy function
def last_four(num):
    return str(num)[-4]

# %%
df['CC Number'].apply(last_four)
# Out:
# 0      3
# 1      9
# 2      1
# 3      5
# 4      7
#       ..
# 239    2
# 240    5
# 241    7
# 242    0
# 243    8
# Name: CC Number, Length: 244, dtype: object

# %%
df['last_four'] = df['CC Number'].apply(last_four)

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID last_four
# 0  Christy Cunningham  3560325168603410    Sun2959         3
# 1      Douglas Tucker  4478071379779230    Sun4608         9
# 2      Travis Walters  6011812112971322    Sun4458         1

# %%
df['total_bill'].mean()
# Out:
# np.float64(19.78594262295082)

# %%
def price_class(price):
    if price < 10:
        return "$"
    elif price >=10 and price <30:
        return "$$"
    else:
        return "$$$"

# %%
df['price_class'] = df['total_bill'].apply(price_class)
df.tail(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID last_four price_class
# 241       Keith Wong  6011891618747196    Sat3880         7          $$
# 242     Dennis Dixon     4375220550950      Sat17         0          $$
# 243  Michelle Hardin  3511451626698139    Thur672         8          $$

# %% [markdown]
# ## `lambda` function

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
def simple(num):
    return num*2

# same funcitons
lambda num: num*2
# Out:
# <function __main__.<lambda>(num)>

# %% [markdown]
# ## `DataFrame.apply` using `lambda` single ***column***

# %%
df['total_bill'].apply(simple)
# Out:
# 0      33.98
# 1      20.68
# 2      42.02
# 3      47.36
# 4      49.18
#        ...
# 239    58.06
# 240    54.36
# 241    45.34
# 242    35.64
# 243    37.56
# Name: total_bill, Length: 244, dtype: float64

# %%
df['total_bill'].apply(lambda num: num*2)
# Out:
# 0      33.98
# 1      20.68
# 2      42.02
# 3      47.36
# 4      49.18
#        ...
# 239    58.06
# 240    54.36
# 241    45.34
# 242    35.64
# 243    37.56
# Name: total_bill, Length: 244, dtype: float64

# %% [markdown]
# ## `DataFrame.apply` using `lambda` single ***row*** conditional

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('tips.csv')
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['total_bill']= df['total_bill'].apply(lambda x: np.square(x) if x ==  23.68	 else x)
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0     16.9900  1.01  Female     No  Sun  Dinner     2              8.49
# 1     10.3400  1.66    Male     No  Sun  Dinner     3              3.45
# 2     21.0100  3.50    Male     No  Sun  Dinner     3              7.00
# 3    560.7424  3.31    Male     No  Sun  Dinner     2             11.84
# 4     24.5900  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
# creating and initializing a nested list
values_list = [[15, 2.5, 100], [20, 4.5, 50], [25, 5.2, 80],
            [45, 5.8, 48], [40, 6.3, 70], [41, 6.4, 90], 
            [51, 2.3, 111]]

# creating a pandas dataframe
df = pd.DataFrame(values_list, columns=['Field_1', 'Field_2', 'Field_3'],
                index=['a', 'b', 'c', 'd', 'e', 'f', 'g'])
df.head(3)
# Out:
#    Field_1  Field_2  Field_3
# a       15      2.5      100
# b       20      4.5       50
# c       25      5.2       80

# %%
# Apply function numpy.square() to square
# the values of one row only i.e. row 
# with index name 'd'
df = df.apply(lambda x: np.square(x) if x.name == 'd' else x, axis=1)
df.head()
# Out:
#    Field_1  Field_2  Field_3
# a     15.0     2.50    100.0
# b     20.0     4.50     50.0
# c     25.0     5.20     80.0
# d   2025.0    33.64   2304.0
# e     40.0     6.30     70.0

# %% [markdown]
# ## `lambda` with `Dataframe.assign()` method

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('tips.csv')
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608

# %%
# Applying lambda function to find 
# percentage of 'total_bill' column in 200
# using df.assign()

df = df.assign(Percentage = lambda x: (x['total_bill'] /200 * 100))
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID  Percentage
# 0  Christy Cunningham  3560325168603410    Sun2959       8.495
# 1      Douglas Tucker  4478071379779230    Sun4608       5.170
# 2      Travis Walters  6011812112971322    Sun4458      10.505

# %%
# Applying lambda function to find
# the product of 2 columns using total_bill,tip
# df.assign()
df = df.assign(sum_total_bill_and_tip = lambda x: (x['total_bill'] +  x['tip']))
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID  Percentage  \
# 0  Christy Cunningham  3560325168603410    Sun2959       8.495
# 1      Douglas Tucker  4478071379779230    Sun4608       5.170
#
#    sum_total_bill_and_tip
# 0                    18.0
# 1                    12.0

# %% [markdown]
# ## `apply()` ***multible*** column using `lambda`

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('tips.csv')
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608

# %%
def quality(total_bill, tip):
    if tip/total_bill > 0.25:
        return "Generous"
    else:
        return "other"

# %%
df['quality'] = df[['total_bill', 'tip']].apply(lambda df: quality(df['total_bill'],df['tip'] ), axis=1)
df.head(4)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
#
#            Payer Name         CC Number Payment ID quality
# 0  Christy Cunningham  3560325168603410    Sun2959   other
# 1      Douglas Tucker  4478071379779230    Sun4608   other
# 2      Travis Walters  6011812112971322    Sun4458   other
# 3    Nathaniel Harris  4676137647685994    Sun5260   other

# %% [markdown]
# ## filter ***multible*** column using `np.vectorize`

# %%
df['quality'] = np.vectorize(quality)(df['total_bill'],df['tip'])
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID quality
# 0    Christy Cunningham  3560325168603410    Sun2959   other
# 1        Douglas Tucker  4478071379779230    Sun4608   other
# 2        Travis Walters  6011812112971322    Sun4458   other
# 3      Nathaniel Harris  4676137647685994    Sun5260   other
# 4          Tonya Carter  4832732618637221    Sun2251   other
# ..                  ...               ...        ...     ...
# 239       Michael Avila  5296068606052842    Sat2657   other
# 240      Monica Sanders  3506806155565404    Sat1766   other
# 241          Keith Wong  6011891618747196    Sat3880   other
# 242        Dennis Dixon     4375220550950      Sat17   other
# 243     Michelle Hardin  3511451626698139    Thur672   other
#
# [244 rows x 12 columns]

# %% [markdown]
# ## time testing

# %%
import numpy as np
import pandas as pd
import timeit

def quality(total_bill, tip):
    if tip/total_bill > 0.25:
        return "Generous"
    else:
        return "other"

df = pd.read_csv('tips.csv')
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608

# %%
# code that must be executed only once
setup_code = """ 
import numpy as np
import pandas as pd
import timeit

df = pd.read_csv('tips.csv')

def quality(total_bill, tip):
    if tip/total_bill > 0.25:
        return "Generous"
    else:
        return "other"
"""

stm_one = """ 
df['quality'] = df[['total_bill', 'tip']].apply(lambda df: quality(df['total_bill'],df['tip'] ), axis=1)
"""

stm_two = """ 
df['quality'] = np.vectorize(quality)(df['total_bill'],df['tip'])
"""

# %%
# single process operation
timeit.timeit(setup = setup_code, stmt = stm_one, number=5000)
# Out:
# 10.941975427000216

# %%
# multy process operation
timeit.timeit(setup = setup_code, stmt = stm_two, number=5000)
# Out:
# 1.6405729050002265

# %% [markdown]
# ## `sort` one ***column***

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('tips.csv')
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.sort_values('tip', ascending=True).head(3)
# Out:
#      total_bill  tip     sex smoker  day    time  size  price_per_person  \
# 92         5.75  1.0  Female    Yes  Fri  Dinner     2              2.88
# 111        7.25  1.0  Female     No  Sat  Dinner     1              7.25
# 67         3.07  1.0  Female    Yes  Sat  Dinner     1              3.07
#
#         Payer Name         CC Number Payment ID
# 92    Leah Ramirez  3508911676966392    Fri3780
# 111    Terri Jones  3559221007826887    Sat4801
# 67   Tiffany Brock  4359488526995267    Sat3455

# %%
df.sort_values('tip', ascending=False).head(3)
# Out:
#      total_bill    tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.00  Male     No  Sat  Dinner     4             12.08
# 23        39.42   7.58  Male     No  Sat  Dinner     4              9.86
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590
# 23    Lance Peterson  3542584061609808     Sat239

# %% [markdown]
# ## `sort` multiple ***column***

# %%
df.sort_values(['tip', 'size'], ascending=True).head(2)
# Out:
#      total_bill  tip     sex smoker  day    time  size  price_per_person  \
# 67         3.07  1.0  Female    Yes  Sat  Dinner     1              3.07
# 111        7.25  1.0  Female     No  Sat  Dinner     1              7.25
#
#         Payer Name         CC Number Payment ID
# 67   Tiffany Brock  4359488526995267    Sat3455
# 111    Terri Jones  3559221007826887    Sat4801

# %% [markdown]
# ## `max`,  `idxmax`, `min`, `idxmin` value

# %%
df['total_bill'].max()
# Out:
# np.float64(50.81)

# %%
df['total_bill'].idxmax()
# Out:
# 170

# %%
df.iloc[170]
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# Name: 170, dtype: object

# %%
df['total_bill'].min()
# Out:
# np.float64(3.07)

# %%
df['total_bill'].idxmin()
# Out:
# 67

# %%
df.iloc[67]
# Out:
# total_bill                      3.07
# tip                              1.0
# sex                           Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                   Sat3455
# Name: 67, dtype: object

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# ## DataFrame `correlation`

# %%
df[['total_bill', 'tip', 'size', 'price_per_person']].corr()
# Out:
#                   total_bill       tip      size  price_per_person
# total_bill          1.000000  0.675734  0.598315          0.647554
# tip                 0.675734  1.000000  0.489299          0.347405
# size                0.598315  0.489299  1.000000         -0.175359
# price_per_person    0.647554  0.347405 -0.175359          1.000000

# %% [markdown]
# ## `Series.value_counts()`, `Series.unique()`, `Series.nunique()`

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['sex'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['sex'].nunique()
# Out:
# 2

# %% [markdown]
# ## `Series.replace('some_string', 'ss')`

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('tips.csv')
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608

# %%
df['sex'].replace('Female', 'F')
# Out:
# 0         F
# 1      Male
# 2      Male
# 3      Male
# 4         F
#        ...
# 239    Male
# 240       F
# 241    Male
# 242    Male
# 243       F
# Name: sex, Length: 244, dtype: object

# %%
df['sex'].replace(['Female', 'Male'], ['F', 'M'])
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %% [markdown]
# ## `Series.map()`

# %%
mymap = {'Female': 'F',
            'Male': 'M'}

df['sex'].map(mymap)
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %% [markdown]
# ## `Series.dubpicated()`

# %%
import pandas as pd 
df = pd.DataFrame({ 
    'Name': ['Alice', 'Bob', 'Alice', 'Charlie', 'Alice', 'Alice'], 
    'Age': [25, 32, 25, 37, 25, 25] 
}) 
# print dublicated values
duplicates = df[df.duplicated()] 
print(duplicates)
# Out:
#     Name  Age
# 2  Alice   25
# 4  Alice   25
# 5  Alice   25

# %%
#  print NOT dublicated values
duplicates = df[~df.duplicated()] 
print(duplicates)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   32
# 3  Charlie   37

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# dtype: bool

# %% [markdown]
# # `drop_duplicatesc`

# %%
df.drop_duplicates()
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   32
# 3  Charlie   37

# %% [markdown]
# # `Series.between(left, right, inclusive='both')`

# %% [markdown]
# leftscalar or list-like
#     Left boundary.
# rightscalar or list-like
#     Right boundary.
# inclusive{“both”, “neither”, “left”, “right”}
#     Include boundaries. Whether to set each bound as closed or open.

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('tips.csv')
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df['size'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 244 entries, 0 to 243
# Series name: size
# Non-Null Count  Dtype
# --------------  -----
# 244 non-null    int64
# dtypes: int64(1)
# memory usage: 2.0 KB

# %%
# default inclusive=both
df['size'].between(2, 4, inclusive='both')
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 239    True
# 240    True
# 241    True
# 242    True
# 243    True
# Name: size, Length: 244, dtype: bool

# %%
# default inclusive=both
df[df['size'].between(2, 5, inclusive='both')]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [236 rows x 11 columns]

# %% [markdown]
# # pandas.DataFrame.nlargest/nsmallest

# %%
df.sort_values('total_bill', ascending=False).iloc[:10]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4             10.78
# 142       41.19   5.00    Male     No  Thur   Lunch     5              8.24
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2             20.27
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590
# 59       Brian Ortiz  6596453823950595    Sat8139
# 156    Ryan Gonzales  3523151482063321    Sun7518
# 182     Jose Parsons  4112207559459910    Sun2337
# 102    Heather Cohen   379771118886604    Sat6240
# 197      Brooke Soto  5544902205760175   Thur9313
# 142     Eric Andrews  4356531761046453   Thur3621
# 184      Stephen Cox  3547798222044029    Sun5140
# 95     Aaron Bentley   180026611638690    Fri9628

# %%
df.nlargest(10, 'total_bill')
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4             10.78
# 142       41.19   5.00    Male     No  Thur   Lunch     5              8.24
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2             20.27
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590
# 59       Brian Ortiz  6596453823950595    Sat8139
# 156    Ryan Gonzales  3523151482063321    Sun7518
# 182     Jose Parsons  4112207559459910    Sun2337
# 102    Heather Cohen   379771118886604    Sat6240
# 197      Brooke Soto  5544902205760175   Thur9313
# 142     Eric Andrews  4356531761046453   Thur3621
# 184      Stephen Cox  3547798222044029    Sun5140
# 95     Aaron Bentley   180026611638690    Fri9628

# %%
df.nsmallest(10, 'total_bill')
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25  1.00  Female     No   Sat  Dinner     1              7.25
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2              3.62
# 149        7.51  2.00    Male     No  Thur   Lunch     2              3.76
# 195        7.56  1.44    Male     No  Thur   Lunch     2              3.78
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2              3.87
# 145        8.35  1.50  Female     No  Thur   Lunch     2              4.18
# 135        8.51  1.25  Female     No  Thur   Lunch     2              4.26
# 126        8.52  1.48    Male     No  Thur   Lunch     2              4.26
#
#           Payer Name         CC Number Payment ID
# 67     Tiffany Brock  4359488526995267    Sat3455
# 92      Leah Ramirez  3508911676966392    Fri3780
# 111      Terri Jones  3559221007826887    Sat4801
# 172      Larry White    30432617123103    Sun9209
# 149   Daniel Robbins  4823139288341889   Thur6321
# 195    Michael White  4865390263095532    Thur697
# 218  Nicholas Archer   340517153733524    Sat4772
# 145        Amy Young     4285454264477   Thur9331
# 135   Rebecca Harris  4320272020376174   Thur6600
# 126   Mario Bradshaw  4524404353861811   Thur6719

# %%
df.sort_values('total_bill', ascending=True).iloc[:10]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25  1.00  Female     No   Sat  Dinner     1              7.25
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2              3.62
# 149        7.51  2.00    Male     No  Thur   Lunch     2              3.76
# 195        7.56  1.44    Male     No  Thur   Lunch     2              3.78
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2              3.87
# 145        8.35  1.50  Female     No  Thur   Lunch     2              4.18
# 135        8.51  1.25  Female     No  Thur   Lunch     2              4.26
# 126        8.52  1.48    Male     No  Thur   Lunch     2              4.26
#
#           Payer Name         CC Number Payment ID
# 67     Tiffany Brock  4359488526995267    Sat3455
# 92      Leah Ramirez  3508911676966392    Fri3780
# 111      Terri Jones  3559221007826887    Sat4801
# 172      Larry White    30432617123103    Sun9209
# 149   Daniel Robbins  4823139288341889   Thur6321
# 195    Michael White  4865390263095532    Thur697
# 218  Nicholas Archer   340517153733524    Sat4772
# 145        Amy Young     4285454264477   Thur9331
# 135   Rebecca Harris  4320272020376174   Thur6600
# 126   Mario Bradshaw  4524404353861811   Thur6719

# %% [markdown]
# # `pandas.DataFrame.sample`

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 29        19.65  3.00  Female     No   Sat  Dinner     2              9.82
# 45        18.29  3.00    Male     No   Sun  Dinner     2              9.14
# 140       17.47  3.50  Female     No  Thur   Lunch     2              8.74
# 147       11.87  1.63  Female     No  Thur   Lunch     2              5.94
# 60        20.29  3.21    Male    Yes   Sat  Dinner     2             10.14
#
#              Payer Name         CC Number Payment ID
# 29       Melinda Murphy  5489272944576051    Sat2467
# 45   Richard Fitzgerald   375156610762053    Sun8643
# 140          Kayla Rios  5233918213804470   Thur3906
# 147  Annette Cunningham      675937746864   Thur4780
# 60       Anthony Mclean   347614304015027    Sat2353

# %%
df.sample(frac=0.05)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 199       13.51  2.00    Male    Yes  Thur   Lunch     2              6.76
# 23        39.42  7.58    Male     No   Sat  Dinner     4              9.86
# 41        17.46  2.54    Male     No   Sun  Dinner     2              8.73
# 98        21.01  3.00    Male    Yes   Fri  Dinner     2             10.50
# 155       29.85  5.14  Female     No   Sun  Dinner     5              5.97
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 128       11.38  2.00  Female     No  Thur   Lunch     2              5.69
# 209       12.76  2.23  Female    Yes   Sat  Dinner     2              6.38
# 228       13.28  2.72    Male     No   Sat  Dinner     2              6.64
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2              8.14
# 211       25.89  5.16    Male    Yes   Sat  Dinner     4              6.47
# 33        20.69  2.45  Female     No   Sat  Dinner     4              5.17
#
#             Payer Name         CC Number Payment ID
# 199   Joseph Murphy MD  6547218923471275   Thur2428
# 23      Lance Peterson  3542584061609808     Sat239
# 41         David Boyer  3536678244278149    Sun9460
# 98          Michael Li  4831801127457917     Fri144
# 155     Madison Wilson  4210875236164664    Sun9176
# 1       Douglas Tucker  4478071379779230    Sun4608
# 128  Christine Perkins  3548391118913991   Thur8551
# 209   Sarah Cunningham   341876516331163    Sat1274
# 228        Glenn Jones      502061651712    Sat2937
# 225     Whitney Arnold  3579111947217428    Fri6665
# 211     Christopher Li  6011962464150569    Sat6735
# 33       Amber Francis   377742985258914    Sat6649

# %% [markdown]
# # missing data

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('tips.csv')
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608

# %%
np.nan
# Out:
# nan

# %%
pd.NA

# %%
pd.NaT
# Out:
# NaT

# %%
np.nan == np.nan
# Out:
# False

# %%
np.nan is np.nan
# Out:
# True

# %%
myvar = np.nan

# %%
myvar is np.nan
# Out:
# True

# %%
df = pd.read_csv('movie_scores.csv')
df.head(4)
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0

# %% [markdown]
# `DataFrame..isnull(); DataFrame..notnull(); `

# %%
# returns boolean True, or false, if value is null,
df.isnull()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0       False      False  False  False            False             False
# 1        True       True   True   True             True              True
# 2       False      False  False  False             True              True
# 3       False      False  False  False            False             False
# 4       False      False  False  False            False             False

# %%
#  returns boolean value, if cell is nut noll
df.notnull()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0        True       True   True   True             True              True
# 1       False      False  False  False            False             False
# 2        True       True   True   True            False             False
# 3        True       True   True   True             True              True
# 4        True       True   True   True             True              True

# %%
df[df.notnull()]
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df[df.notna()]
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df['pre_movie_score'].notnull()
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# Name: pre_movie_score, dtype: bool

# %%
# 
df[df['pre_movie_score'].notnull()]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df[df['pre_movie_score'].isnull()]
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN

# %% [markdown]
# `df['pre_movie_score'].isnull()) & (df['first_name'].notnull())` conditional filtering

# %%
df[(df['pre_movie_score'].isnull()) & (df['first_name'].notnull())]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 2       Hugh   Jackman  51.0   m              NaN               NaN

# %% [markdown]
# # keep data, drop data, fill data

# %% [markdown]
# # `df.dropna(thresh=1)`

# %%
df = pd.read_csv('movie_scores.csv')
# help(df.dropna())
df.dropna()  # any row with any missing values
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df.head()
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
# do not drop if row has at least 1 NOT null value
df.dropna(thresh=1)
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
# do not drop if row has at least 4 NOT null value
df.dropna(thresh=4)
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
# do not drop if row has at least 5 NOT null value
df.dropna(thresh=5)
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
# drop columns that have any missing values
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %% [markdown]
# # `pandas.DataFrame..dropna(subset=['coolumn_name'])`

# %%
df.dropna(subset=['last_name'])
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %% [markdown]
# # `pandas.DataFrame.fillna('new_value')`

# %%
df = pd.read_csv('movie_scores.csv')
# help(df.dropna())
df.head()
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df.fillna('NEW_VALUE')
# Out:
#   first_name  last_name        age        sex pre_movie_score post_movie_score
# 0        Tom      Hanks       63.0          m             8.0             10.0
# 1  NEW_VALUE  NEW_VALUE  NEW_VALUE  NEW_VALUE       NEW_VALUE        NEW_VALUE
# 2       Hugh    Jackman       51.0          m       NEW_VALUE        NEW_VALUE
# 3      Oprah    Winfrey       66.0          f             6.0              8.0
# 4       Emma      Stone       31.0          f             7.0              9.0

# %%
df['pre_movie_score'].fillna(0)
# Out:
# 0    8.0
# 1    0.0
# 2    0.0
# 3    6.0
# 4    7.0
# Name: pre_movie_score, dtype: float64

# %%
df['pre_movie_score'] = df['pre_movie_score'].fillna(0)
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              0.0               NaN
# 2       Hugh   Jackman  51.0    m              0.0               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df['pre_movie_score'].mean()
# Out:
# np.float64(4.2)

# %%
df = pd.read_csv('movie_scores.csv')
# help(df.dropna())
df['pre_movie_score'] = df['pre_movie_score'].fillna(df['pre_movie_score'].mean())
df.head()
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              7.0               NaN
# 2       Hugh   Jackman  51.0    m              7.0               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df = pd.read_csv('movie_scores.csv')
df.fillna(df.mean())  # it works for numerical calues, not for streengs,

# %% [markdown]
# # `pandas.Series.interpolate`

# %%
airline_tix = {'first':100,'business':np.nan,'economy-plus':50,'economy':30}
ser = pd.Series(airline_tix)
ser
# Out:
# first           100.0
# business          NaN
# economy-plus     50.0
# economy          30.0
# dtype: float64

# %%
ser.interpolate()
# Out:
# first           100.0
# business         75.0
# economy-plus     50.0
# economy          30.0
# dtype: float64

# %% [markdown]
# # `pandas.DataFrame.groupby()`

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('mpg.csv')
df.head(3)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite

# %%
# horsepower is object
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df['model_year'].unique()
# Out:
# array([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82])

# %%
# Convert 'horsepower' column to numeric
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')

# %%
# Drop rows with missing values in 'weight'
df = df.dropna(subset=['horsepower'])
# Alternatively, fill missing values with some value (e.g., median of 'weight')
df['horsepower'].fillna(df['horsepower'].median(), inplace=True)
# Out:
# /tmp/ipykernel_15869/1657209473.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['horsepower'].fillna(df['horsepower'].median(), inplace=True)

# %%
df[['mpg', 'cylinders', 'displacement', 'horsepower', 'weight','acceleration', 'model_year', 'origin']]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# 4            70       1
# ..          ...     ...
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1
#
# [392 rows x 8 columns]

# %%
df[['mpg', 'weight','cylinders', 'displacement', 'acceleration', 'model_year', 'origin', 'horsepower']].groupby('model_year').mean()
# Out:
#                   mpg       weight  cylinders  displacement  acceleration  \
# model_year
# 70          17.689655  3372.793103   6.758621    281.413793     12.948276
# 71          21.111111  3030.592593   5.629630    213.888889     15.000000
# 72          18.714286  3237.714286   5.821429    218.375000     15.125000
# 73          17.100000  3419.025000   6.375000    256.875000     14.312500
# 74          22.769231  2878.038462   5.230769    170.653846     16.173077
# 75          20.266667  3176.800000   5.600000    205.533333     16.050000
# 76          21.573529  3078.735294   5.647059    197.794118     15.941176
# 77          23.375000  2997.357143   5.464286    191.392857     15.435714
# 78          24.061111  2861.805556   5.361111    177.805556     15.805556
# 79          25.093103  3055.344828   5.827586    206.689655     15.813793
# 80          33.803704  2441.592593   4.148148    116.074074     17.018519
# 81          30.185714  2530.178571   4.642857    136.571429     16.325000
# 82          32.000000  2434.166667   4.200000    128.133333     16.510000
#
#               origin  horsepower
# model_year
# 70          1.310345  147.827586
# 71          1.444444  107.037037
# 72          1.535714  120.178571
# 73          1.375000  130.475000
# 74          1.692308   94.230769
# 75          1.466667  101.066667
# 76          1.470588  101.117647
# 77          1.571429  105.071429
# 78          1.611111   99.694444
# 79          1.275862  101.206897
# 80          2.259259   77.481481
# 81          1.964286   81.035714
# 82          1.666667   81.466667

# %%
df[['mpg', 'weight','cylinders', 'displacement', 'acceleration', 'model_year', 'origin', 'horsepower']].groupby(['model_year', 'cylinders']).mean()
# Out:
#                             mpg       weight  displacement  acceleration  \
# model_year cylinders
# 70         4          25.285714  2292.571429    107.000000     16.000000
#            6          20.500000  2710.500000    199.000000     15.500000
#            8          14.111111  3940.055556    367.555556     11.194444
# 71         4          27.666667  2057.250000    102.166667     16.791667
#            6          18.000000  3171.875000    243.375000     14.750000
#            8          13.428571  4537.714286    371.714286     12.214286
# 72         3          19.000000  2330.000000     70.000000     13.500000
#            4          23.428571  2382.642857    111.535714     17.214286
#            8          13.615385  4228.384615    344.846154     13.000000
# 73         3          18.000000  2124.000000     70.000000     13.500000
#            4          22.727273  2338.090909    109.272727     17.136364
#            6          19.000000  2917.125000    212.250000     15.687500
#            8          13.200000  4279.050000    365.250000     12.250000
# 74         4          27.800000  2151.466667     96.533333     16.400000
#            6          17.333333  3394.166667    235.500000     16.833333
#            8          14.200000  4438.400000    315.200000     14.700000
# 75         4          25.250000  2489.250000    114.833333     15.833333
#            6          17.583333  3398.333333    233.750000     17.708333
#            8          15.666667  4108.833333    330.500000     13.166667
# 76         4          26.766667  2306.600000    106.333333     16.866667
#            6          20.000000  3349.600000    221.400000     17.000000
#            8          14.666667  4064.666667    324.000000     13.222222
# 77         3          21.500000  2720.000000     80.000000     13.500000
#            4          29.107143  2205.071429    106.500000     16.064286
#            6          19.500000  3383.000000    220.400000     16.900000
#            8          16.000000  4177.500000    335.750000     13.662500
# 78         4          29.576471  2296.764706    112.117647     16.282353
#            5          20.300000  2830.000000    131.000000     15.900000
#            6          19.066667  3314.166667    213.250000     16.391667
#            8          19.050000  3563.333333    300.833333     13.266667
# 79         4          31.525000  2357.583333    113.583333     15.991667
#            5          25.400000  3530.000000    183.000000     20.100000
#            6          22.950000  3025.833333    205.666667     15.433333
#            8          18.630000  3862.900000    321.400000     15.400000
# 80         3          23.700000  2420.000000     70.000000     12.500000
#            4          34.817391  2359.217391    110.869565     17.260870
#            5          36.400000  2950.000000    121.000000     19.900000
#            6          25.900000  3145.500000    196.500000     15.050000
# 81         4          32.730000  2273.250000    109.300000     16.500000
#            6          23.428571  3093.571429    184.000000     15.442857
#            8          26.600000  3725.000000    350.000000     19.000000
# 82         4          32.407407  2378.888889    117.370370     16.562963
#            6          28.333333  2931.666667    225.000000     16.033333
#
#                         origin  horsepower
# model_year cylinders
# 70         4          2.285714   87.714286
#            6          1.000000   91.750000
#            8          1.000000  183.666667
# 71         4          2.000000   77.583333
#            6          1.000000   98.875000
#            8          1.000000  166.857143
# 72         3          3.000000   97.000000
#            4          1.928571   85.142857
#            8          1.000000  159.692308
# 73         3          3.000000   90.000000
#            4          2.000000   82.909091
#            6          1.250000  102.125000
#            8          1.000000  170.000000
# 74         4          2.200000   74.000000
#            6          1.000000  101.666667
#            8          1.000000  146.000000
# 75         4          2.166667   84.916667
#            6          1.000000   96.750000
#            8          1.000000  142.000000
# 76         4          1.866667   75.600000
#            6          1.300000   98.700000
#            8          1.000000  146.333333
# 77         3          3.000000  110.000000
#            4          1.857143   78.785714
#            6          1.400000  102.000000
#            8          1.000000  152.375000
# 78         4          2.117647   79.705882
#            5          2.000000  103.000000
#            6          1.166667  109.833333
#            8          1.000000  135.500000
# 79         4          1.583333   75.750000
#            5          2.000000   77.000000
#            6          1.000000  105.000000
#            8          1.000000  131.900000
# 80         3          3.000000  100.000000
#            4          2.260870   74.043478
#            5          2.000000   67.000000
#            6          2.000000  111.000000
# 81         4          2.100000   72.950000
#            6          1.714286  100.714286
#            8          1.000000  105.000000
# 82         4          1.740741   79.148148
#            6          1.000000  102.333333
